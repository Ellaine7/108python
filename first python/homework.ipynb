# %% [markdown]
# # python計算機功能

# %% [markdown]
# ## 1+1

# %%
3**3 # 3的3次方
# Out:
# 27

# %%
(200+100)*2/10
# Out:
# 60.0

# %%
a=(200+100)*2/10

# %%
a
# Out:
# 60.0

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # plt.plot折線圖
# # plt.scatter 散佈圖

# %%
plt.plot([2,-5, 6,-10,9])

# %%
x=[0,1.1,2.5,3.2,4.8]
y=[2.1,3.4,1,5,7]

# %%
plt.plot(x,y)

# %%
np.random.randn(10)
# Out:
# array([ 0.26554058,  0.93136924, -0.77090192,  0.66025988,  1.15463871,
#        -1.14407285,  1.56913782,  0.37006419, -0.94084549,  1.59768187])

# %%
plt.plot(np.random.randn(10))

# %%
plt.plot(np.random.randn(100))
